# %% [markdown]
# # Data analysis ring
#
# We analyze the following ring samples from the edx course
#
# Double-bus ring resonators
# symmetrically coupled
#
# TE:
# R = [3]
# g = [50, 100, 150]
#
# R = [10]
# g = [50, 100, 150, 200]
#
# TM:
# R = [30]
# g = [150, 200, 250]

# %%
import matplotlib.pyplot as plt
import numpy as np
import ubcpdk
# Out:
# 2022-02-14 07:08:55.041 | INFO     | gdsfactory.config:<module>:52 - Load '/home/jmatres/gdsfactory/gdsfactory' 4.1.6
# 2022-02-14 07:08:55.994 | INFO     | ubcpdk:<module>:27 - Found UBCpdk '1.1.1' installed at PosixPath('/home/jmatres/ubc/ubcpdk')

# %%
w, p = ubcpdk.data.read_mat(ubcpdk.PATH.ring_te_r3_g100, port=0)
plt.plot(w * 1e9, p)
